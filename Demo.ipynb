# %%
# importing csv module
import csv
  
# importing string functions


# csv file name
filename = "demo.csv"
  
# initializing the titles and rows list
fields = []
rows = []
  
# reading csv file
with open(filename, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
      
    # extracting field names through first row
    fields = next(csvreader)
  
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
  
    # get total number of rows
 #   print("Total no. of rows: %d"%(csvreader.line_num))
  
# printing the field names
bv=csvreader.line_num
#print('Field names are:' + ', '.join(field for field in fields))
  
#  printing first 5 rows
#print('\nFirst 5 rows are:\n')
#for row in rows[:5]:
    # parsing each column of a row
 #   for col in row:
  #      print("%10s"%col),
   # print('\n')

n = int(input("Enter the number of students appeared: "))

lim=csvreader.line_num
f = 1000
l1=[0.0]*f
l2=[0]*f
ins=0
co1=0
for co in range (0,n):
    sdf=rows[co][0]
    # print (sdf)
    temp1 = sdf[22:27]
    # temp2 = sdf[77:81]
    # temp3 = temp2.strip()           #check
    if (temp1 == '-----'):
        temp1 = 0
    sgpa = float(temp1)
    # cp = temp2              #check
    l1[co1] = sgpa
    # l2[co1] = cp
    # print (co1 + 1, sgpa, cp)
    co1 = co1 + 1

print ('\n')
print ("Sr.\t SGPA")
for i in range (0,n):
    print (i + 1, '\t', l1[i])
    
print ('\n')
x=sum(l1)/n                                   # number of rows 
print ('Average SGPA:', round(x,4))
f = 0
d = 0
fc = 0
sc = 0
p = 0
for j in range (0,n):
    if (l1[j] < 7):
        f = f + 1
    if (l1[j] >= 7 and l1[j] < 7.5):
        p = p +1
    if (l1[j] >= 7.5 and l1[j] < 8):
        sc = sc + 1
    if (l1[j] >= 8 and l1[j] < 9):
        fc = fc + 1
    if (l1[j] >= 9):
        d = d + 1
total = d+fc+sc+p+f

pd = d/total*100
pfc = fc/total*100
psc = sc/total*100
pp = p/total*100
pf = f/total*100

percent = pd+pfc+psc+pp+pf

print ("\nStudents with distinction:", d)
print ("Students with first class:", fc)
print ("Students with second class:", sc)
print ("Students with pass class:", p)
print ("Students who failed:", f)
print ("Total students:", total)

print ("\nPercentage of students with distinction:", round(pd,3), '%')
print ("Percentage of students with first class:", round(pfc,3), '%')
print ("Percentage of students with second class:", round(psc,3), '%')
print ("Percentage of students with pass class:", round(pp,3), '%')
print ("Percentage of students who failed:", round(pf,3), '%')
# print ("Percentage accounted for:", percent)
# Out:
# Enter the number of students appeared: 781
#
#
# Sr.	 SGPA
# 1 	 7.318
# 2 	 0.0
# 3 	 0.0
# 4 	 8.273
# 5 	 8.682
# 6 	 9.091
# 7 	 8.909
# 8 	 8.545
# 9 	 7.455
# 10 	 8.5
# 11 	 8.682
# 12 	 0.0
# 13 	 0.0
# 14 	 0.0
# 15 	 8.955
# 16 	 8.5
# 17 	 7.636
# 18 	 9.0
# 19 	 9.409
# 20 	 0.0
# 21 	 8.591
# 22 	 6.864
# 23 	 8.591
# 24 	 7.045
# 25 	 9.273
# 26 	 0.0
# 27 	 8.227
# 28 	 8.636
# 29 	 0.0
# 30 	 0.0
# 31 	 8.818
# 32 	 7.455
# 33 	 8.0
# 34 	 8.955
# 35 	 6.818
# 36 	 8.182
# 37 	 8.227
# 38 	 0.0
# 39 	 8.455
# 40 	 7.045
# 41 	 8.818
# 42 	 0.0
# 43 	 9.227
# 44 	 0.0
# 45 	 0.0
# 46 	 7.955
# 47 	 0.0
# 48 	 8.273
# 49 	 0.0
# 50 	 8.591
# 51 	 8.636
# 52 	 8.091
# 53 	 9.0
# 54 	 8.136
# 55 	 9.409
# 56 	 9.045
# 57 	 7.5
# 58 	 8.773
# 59 	 0.0
# 60 	 8.818
# 61 	 8.182
# 62 	 7.227
# 63 	 8.773
# 64 	 8.545
# 65 	 8.727
# 66 	 9.409
# 67 	 7.318
# 68 	 8.682
# 69 	 9.0
# 70 	 7.773
# 71 	 7.682
# 72 	 7.955
# 73 	 7.682
# 74 	 8.318
# 75 	 7.636
# 76 	 0.0
# ...

# %%
# importing csv module
import csv
  
# importing string functions


# csv file name
filename = "demo.csv"
  
# initializing the titles and rows list
fields = []
rows = []
  
# reading csv file
with open(filename, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)
      
    # extracting field names through first row
    fields = next(csvreader)
  
    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)
  
    # get total number of rows
 #   print("Total no. of rows: %d"%(csvreader.line_num))
  
# printing the field names
bv=csvreader.line_num
#print('Field names are:' + ', '.join(field for field in fields))
  
#  printing first 5 rows
#print('\nFirst 5 rows are:\n')
#for row in rows[:5]:
    # parsing each column of a row
 #   for col in row:
  #      print("%10s"%col),
   # print('\n')

n = int(input("Enter the number of students appeared: "))

lim=csvreader.line_num
f = 1000
l1=[0.0]*f
l2=[0]*f
ins=0
co1=0
for co in range (0,n):
    sdf=rows[co][0]
    # print (sdf)
    temp1 = sdf[22:27]
    # temp2 = sdf[77:81]
    # temp3 = temp2.strip()           #check
    if (temp1 == '-----'):
        temp1 = 0
    sgpa = float(temp1)
    # cp = temp2              #check
    l1[co1] = sgpa
    # l2[co1] = cp
    # print (co1 + 1, sgpa, cp)
    co1 = co1 + 1

print ('\n')
print ("Sr.\t SGPA")
for i in range (0,n):
    print (i + 1, '\t', l1[i])
    
print ('\n')
x=sum(l1)/n                                   # number of rows 
print ('Average SGPA:', round(x,4))
f = 0
d = 0
fc = 0
sc = 0
p = 0
for j in range (0,n):
    if (l1[j] < 7):
        f = f + 1
    if (l1[j] >= 7 and l1[j] < 7.5):
        p = p +1
    if (l1[j] >= 7.5 and l1[j] < 8):
        sc = sc + 1
    if (l1[j] >= 8 and l1[j] < 9):
        fc = fc + 1
    if (l1[j] >= 9):
        d = d + 1
total = d+fc+sc+p+f

pd = d/total*100
pfc = fc/total*100
psc = sc/total*100
pp = p/total*100
pf = f/total*100

percent = pd+pfc+psc+pp+pf

print ("\nStudents with distinction:", d)
print ("Students with first class:", fc)
print ("Students with second class:", sc)
print ("Students with pass class:", p)
print ("Students who failed:", f)
print ("Total students:", total)

print ("\nPercentage of students with distinction:", round(pd,3), '%')
print ("Percentage of students with first class:", round(pfc,3), '%')
print ("Percentage of students with second class:", round(psc,3), '%')
print ("Percentage of students with pass class:", round(pp,3), '%')
print ("Percentage of students who failed:", round(pf,3), '%')
# print ("Percentage accounted for:", percent)
# Out:
# Enter the number of students appeared: 50
#
#
# Sr.	 SGPA
# 1 	 7.318
# 2 	 0.0
# 3 	 0.0
# 4 	 8.273
# 5 	 8.682
# 6 	 9.091
# 7 	 8.909
# 8 	 8.545
# 9 	 7.455
# 10 	 8.5
# 11 	 8.682
# 12 	 0.0
# 13 	 0.0
# 14 	 0.0
# 15 	 8.955
# 16 	 8.5
# 17 	 7.636
# 18 	 9.0
# 19 	 9.409
# 20 	 0.0
# 21 	 8.591
# 22 	 6.864
# 23 	 8.591
# 24 	 7.045
# 25 	 9.273
# 26 	 0.0
# 27 	 8.227
# 28 	 8.636
# 29 	 0.0
# 30 	 0.0
# 31 	 8.818
# 32 	 7.455
# 33 	 8.0
# 34 	 8.955
# 35 	 6.818
# 36 	 8.182
# 37 	 8.227
# 38 	 0.0
# 39 	 8.455
# 40 	 7.045
# 41 	 8.818
# 42 	 0.0
# 43 	 9.227
# 44 	 0.0
# 45 	 0.0
# 46 	 7.955
# 47 	 0.0
# 48 	 8.273
# 49 	 0.0
# 50 	 8.591
#
#
# Average SGPA: 5.82
#
# Students with distinction: 5
# Students with first class: 21
# Students with second class: 2
# Students with pass class: 5
# Students who failed: 17
# Total students: 50
#
# Percentage of students with distinction: 10.0 %
# Percentage of students with first class: 42.0 %
# ...
